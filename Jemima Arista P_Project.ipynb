# %% [markdown]
# # Prepocessing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('cardio_train.csv','sep',',')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
# id             70000 non-null int64
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
data = data.replace(' ?', np.nan)

# %%
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.info() #tidak terdapat missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
# id             70000 non-null int64
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
plt.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
# Univariate Density Plots
data.plot(kind= 'density ' , subplots=True, layout=(8,4), sharex=False)
plt.show()

# %%
#Univariate Boxplots
data.plot(kind='box', subplots=True, layout=(8,4), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data['cardio'] = LabelEncoder().fit_transform(data['cardio'])
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.describe() ##statistika deskriptif
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# std      154.011419    188.472530      0.680250      0.572270      0.283484
# min     -150.000000    -70.000000      1.000000      1.000000      0.000000
# 25%      120.000000     80.000000      1.000000      1.000000      0.000000
# 50%      120.000000     80.000000      1.000000      1.000000      0.000000
# 75%      140.000000     90.000000      2.000000      1.000000      0.000000
# max    16020.000000  11000.000000      3.000000      3.000000      1.000000
#
#                alco        active        cardio
# count  70000.000000  70000.000000  70000.000000
# mean       0.053771      0.803729      0.499700
# std        0.225568      0.397179      0.500003
# min        0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000
# 50%        0.000000      1.000000      0.000000
# 75%        0.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000

# %% [markdown]
# # KNN

# %%
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
sns.countplot(x=data['cardio'])

# %%
g=sns.PairGrid(data,hue="cardio")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()
plt.show()

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
from sklearn.model_selection import KFold, cross_val_score
y=data['cardio']
x1=data.drop(['id','cardio'],axis=1)
k_fold = KFold(n_splits=10)
akurasi = cross_val_score(knn, x, y, cv=k_fold, scoring='accuracy')
presisi = cross_val_score(knn, x, y, cv=k_fold, scoring='precision')
recall = cross_val_score(knn, x, y, cv=k_fold, scoring='recall')
AUCScore = cross_val_score(knn, x, y, cv=k_fold, scoring='roc_auc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0e18366f2f1c> in <module>
#       3 x1=data.drop(['id','cardio'],axis=1)
#       4 k_fold = KFold(n_splits=10)
# ----> 5 akurasi = cross_val_score(knn, x, y, cv=k_fold, scoring='accuracy')
#       6 presisi = cross_val_score(knn, x, y, cv=k_fold, scoring='precision')
#       7 recall = cross_val_score(knn, x, y, cv=k_fold, scoring='recall')
#
# NameError: name 'x' is not defined

# %%
print (akurasi)
print (presisi)
print (recall)
print (AUCScore)
# Out:
# [0.789 0.877 0.93  0.965 0.982 0.982 0.93  0.93  0.912 0.946]
# [1.    0.895 0.905 0.964 1.    1.    0.875 0.8   0.75  0.857]
# [0.739 0.773 0.905 0.964 0.964 0.917 0.875 0.923 0.923 0.923]
# [0.945 0.954 0.941 0.995 0.999 0.955 0.93  0.976 0.965 0.993]

# %%
print (akurasi.mean())
print (presisi.mean())
print (recall.mean())
print (AUCScore.mean())
# Out:
# 0.9244674185463658
# 0.9045927318295739
# 0.8906088476740651
# 0.9652067313639987

# %%
k_range = range(5,10)
k_akurasi = []
k_presisi = []
k_recall = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    akurasi =  cross_val_score(knn, x, y, cv= k_fold, scoring='accuracy')
    k_akurasi.append(akurasi.mean())
    presisi =  cross_val_score(knn, x, y, cv= k_fold, scoring='precision')
    k_presisi.append(presisi.mean())
    recall =  cross_val_score(knn, x, y, cv= k_fold, scoring='recall')
    k_recall.append(recall.mean())

# %%
print (k_akurasi)
print (k_presisi)
print (k_recall)
# Out:
# [0.9244674185463658, 0.9192042606516291, 0.919235588972431, 0.9139411027568922, 0.913941102756892]
# [0.9045927318295739, 0.9184022556390978, 0.8891546677150393, 0.9080130473241927, 0.887821741382113]
# [0.8906088476740651, 0.8719753073013943, 0.9002481214437736, 0.8672134025394895, 0.8889843851800373]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot (k_range, k_akurasi, color='red')
plt.plot (k_range, k_presisi, color='blue')
plt.plot (k_range, k_recall, color='yellow')
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Value')
# Out:
# Text(0, 0.5, 'Cross-Validated Value')

# %% [markdown]
# # Training Testing

# %%
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('training.csv','sep',',')

# %%
test = pd.read_csv('testing.csv','sep',',')

# %%
train.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   4  17474       1     156    56.0    100     60            1     1      0
# 3   8  21914       1     151    67.0    120     80            2     2      0
# 4  12  22584       2     178    95.0    130     90            3     3      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       0
# 3     0       0       0
# 4     0       1       1

# %%
y_train=train['cardio']
X_train=data.drop(['id','cardio'],axis=1)
y_test=test['cardio']
X_train=data.drop(['id','cardio'],axis=1)

# %%
knn=KNeighborsClassifier(n_neighbors=5,weights='uniform')

# %%
knn.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-889312abc571> in <module>
# ----> 1 knn.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     889         """
#     890         if not isinstance(X, (KDTree, BallTree)):
# --> 891             X, y = check_X_y(X, y, "csr", multi_output=True)
#     892
#     893         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     764         y = y.astype(np.float64)
#     765
# --> 766     check_consistent_length(X, y)
#     767
#     768     return X, y
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [70000, 49000]

# %%
# nilai ketepatan klasifikasi berdasarkan data training
knn.score(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-39-23807c94bae7> in <module>
#       1 # nilai ketepatan klasifikasi berdasarkan data training
# ----> 2 knn.score(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     286         """
#     287         from .metrics import accuracy_score
# --> 288         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     289
#     290
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     147         X = check_array(X, accept_sparse='csr')
#     148
# --> 149         neigh_dist, neigh_ind = self.kneighbors(X)
#     150         classes_ = self.classes_
#     151         _y = self._y
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in kneighbors(self, X, n_neighbors, return_distance)
#     383
#     384         """
# --> 385         check_is_fitted(self, "_fit_method")
#     386
#     387         if n_neighbors is None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This KNeighborsClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
y_predict= knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
conf_matrix = confusion_matrix(y_test,y_predict)
print(conf_matrix)
# Out:
# [[71  2]
#  [ 5 36]]

# %%
diagnosis = data['diagnosis'].unique()
conf_matrix_df=pd.DataFrame(data=conf_matrix,columns=diagnosis, index=diagnosis)

# %%
conf_matrix_df
# Out:
#     1   0
# 1  71   2
# 0   5  36

# %%
akurasi=accuracy_score(y_test,y_predict)
akurasi
# Out:
# 0.9385964912280702

# %%
sns.heatmap(conf_matrix_df,annot=True,cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.model_selection import train_test_split

# %%
X1=data.drop(['id','diagnosis'],axis=1)
X=X1[['radius_worst','concavity_worst','concavity_mean']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=123)

# %%
from sklearn.naive_bayes import GaussianNB
nb= GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
nb.score(X_train, y_train)
# Out:
# 0.9296703296703297

# %%
ynb_predict= nb.predict(X_test)
ynb_proba= nb.predict_proba(X_test)

# %%
nb_predict=nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
conf_matrixnb= confusion_matrix(y_test, ynb_predict)
print(conf_matrixnb)
# Out:
# [[72  1]
#  [ 5 36]]

# %%
Class= data['diagnosis'].unique()
conf_matrix_df= pd.DataFrame(data=conf_matrixnb, columns=Class, index=Class)
conf_matrix_df
# Out:
#     1   0
# 1  72   1
# 0   5  36

# %%
akurasi=accuracy_score(y_test,nb_predict)
presisi=precision_score(y_test,nb_predict)
recalls=recall_score(y_test,nb_predict)
print(akurasi)
print(presisi)
print(recalls)
# Out:
# 0.9473684210526315
# 0.972972972972973
# 0.8780487804878049

# %%
fpr,tpr,thresholds=roc_curve(y_test,nb_predict)
auc=auc(fpr,tpr)
print('auc = ',auc)
# Out:
# auc =  0.9321750751754091

# %% [markdown]
# sns.heatmap(conf_matrix_df, annot=True, cmap="YlGnBu")
# plt.show()

# %%
correlations= data1.corr()
correlations
# Out:
#                  diagnosis  radius_worst  concavity_worst  concavity_mean
# diagnosis         1.000000      0.776454         0.659610        0.696360
# radius_worst      0.776454      1.000000         0.573975        0.688236
# concavity_worst   0.659610      0.573975         1.000000        0.884103
# concavity_mean    0.696360      0.688236         0.884103        1.000000

# %%
f,ax=plt.subplots(figsize=(10,10))
sns.heatmap(correlations, annot=True, linewidths=5, fmt='.1f', ax=ax)
plt.title("Correlation between Columns of DataFrame", y=1.08)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['diagnosis'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('diagnosis')
ax[0].set_ylabel('')
sns.countplot('diagnosis', data=data, ax=ax[1])
ax[1].set_title('diagnosis')
plt.show()

# %% [markdown]
# # Regresi Logistik

# %%
from sklearn.model_selection import train_test_split

# %%
y=data['diagnosis']
X1=data.drop(['id','diagnosis'],axis=1)
X=X1[['radius_worst','concavity_worst','concavity_mean']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=123)

# %%
#REGLOG
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression(random_state=0)
model = lg.fit(X_train,y_train)
# Out:
# C:\Users\Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
lg.score(X_train,y_train)
# Out:
# 0.9362637362637363

# %%
lg_predict=lg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
conf_matrixlg=confusion_matrix(y_test,lg_predict)
print(conf_matrixlg)
# Out:
# [[73  0]
#  [ 3 38]]

# %%
Class=data['diagnosis'].unique()
conf_matrix_df=pd.DataFrame(data=conf_matrixlg,columns=Class,index=Class)
conf_matrix_df
# Out:
#     1   0
# 1  73   0
# 0   3  38

# %%
akurasi=accuracy_score(y_test,lg_predict)
presisi=precision_score(y_test,lg_predict)
recalls=recall_score(y_test,lg_predict)

# %%
print(akurasi)
print(presisi)
print(recalls)
# Out:
# 0.9736842105263158
# 1.0
# 0.926829268292683

# %%
fpr,tpr,thresholds=roc_curve(y_test,lg_predict)
auc=auc(fpr,tpr)
print('auc = ',auc)
# Out:
# auc =  0.9634146341463414

# %% [markdown]
# # Diskriminan

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
dis= LinearDiscriminantAnalysis ()
dis.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)

# %%
dis.score(X_train, y_train)
# Out:
# 0.9252747252747253

# %%
dis_predict=dis.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
conf_matrixdis = confusion_matrix(y_test, dis_predict)
print(conf_matrixdis)
# Out:
# [[73  0]
#  [ 7 34]]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
Class=data['diagnosis'].unique()
conf_matrix_df=pd.DataFrame(data=conf_matrixdis,columns=Class,index=Class)
conf_matrix_df
# Out:
#     1   0
# 1  73   0
# 0   7  34

# %%
akurasi=accuracy_score(y_test,dis_predict)
presisi=precision_score(y_test,dis_predict)
recalls=recall_score(y_test,dis_predict)

# %%
print(akurasi)
print(presisi)
print(recalls)
# Out:
# 0.9385964912280702
# 1.0
# 0.8292682926829268

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
fpr,tpr,thresholds=roc_curve(y_test,dis_predict)
auc=auc(fpr,tpr)
print('auc = ',auc)
# Out:
# auc =  0.9146341463414633

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 
rf=RandomForestClassifier(n_estimators=10)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.score(X_train, y_train)
# Out:
# 0.9978021978021978

# %%
rf_predict=rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
conf_matrixrf= confusion_matrix(y_test, rf_predict)
print(conf_matrixrf)
# Out:
# [[72  1]
#  [ 4 37]]

# %%
akurasi=accuracy_score(y_test,rf_predict)
presisi=precision_score(y_test,rf_predict)
recalls=recall_score(y_test,rf_predict)

print(akurasi)
print(presisi)
print(recalls)
# Out:
# 0.956140350877193
# 0.9736842105263158
# 0.9024390243902439

# %%
fpr,tpr,thresholds=roc_curve(y_test,rf_predict)
auc=auc(fpr,tpr)
print('auc = ',auc)
# Out:
# auc =  0.9443701971266286

# %% [markdown]
# # SVM

# %%
from sklearn import svm

# %%
random_state = np.random.RandomState(0)
svclin = svm.SVC(kernel='linear',probability=True,
                random_state=random_state)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, auc, roc_curve, recall_score

# %%
k_fold=StratifiedKFold(n_splits=3)

# %%
akurasi=cross_val_score(svclin,X, y, cv=k_fold, scoring='accuracy')
presisi=cross_val_score(svclin,X, y, cv=k_fold, scoring='precision')
recallss=cross_val_score(svclin,X, y, cv=k_fold, scoring='recall')

# %%
akurasi=np.array(akurasi)
presisis=np.array(presisi)
recallss=np.array(recallss)
print(akurasi)
print(presisi)
print(recallss)
# Out:
# [0.911 0.953 0.921]
# [0.95  0.956 0.867]
# [0.803 0.915 0.929]

# %%
print(akurasi.mean())
print(presisi.mean())
print(recallss.mean())
# Out:
# 0.9279309384572542
# 0.9241830065359476
# 0.8822937625754527

# %%
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc

# %%
random_state=np.random.RandomState(0)
n_samples, n_features=X.shape
X=np.c_[X, random_state.randn(n_samples, 200*n_features)]

cv=StratifiedKFold(n_splits=3)
classifier = svm.SVC(kernel='linear', probability=True,
                    random_state=random_state)

tprs = []
aucs = []
mean_fpr = np.linspace(0,1,100)

i=0
for train, test in cv.split(X,y):
    probas_ = classifier.fit(X[train], y[train]).predict_proba(X[test])
    #Compute ROC Curve and area the curve
    fpr, tpr, thresholds = roc_curve(y[test],probas_[:,1])
    tprs.append(interp(mean_fpr,fpr,tpr))
    tprs[-1][0]=0.0
    roc_auc = auc(fpr,tpr)
    aucs.append(roc_auc)
    plt.plot(fpr, tpr, lw=1, alpha=0.3, label='ROC fold %d (AUC=%0.2f)'% (i, roc_auc))
    i += 1
    
plt.plot([0,1],[0,1],linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr=np.mean(tprs, axis=0)
mean_tpr[-1]=1.0
mean_auc=auc(mean_fpr, mean_tpr)
std_auc=np.std(aucs)
plt.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC=%0.2f $\pm$ %0.2f)'% (mean_auc, std_auc),
        lw=2, alpha=0.8)

std_tpr=np.std(tprs, axis=0)
tprs_upper=np.minimum(mean_tpr + std_tpr,1)
tprs_lower=np.maximum(mean_tpr - std_tpr, 0)
plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating charachteristic example')
plt.legend(loc='lower right')
plt.show()
